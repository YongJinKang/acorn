# %%
from matplotlib.image import imread
import os
image = imread("C:/app/workspace/pythonworkspace/venv/ML/unsupervised_learning/강용진반명함-02.jpg")
image.shape
# Out:
# (1200, 900, 3)

# %%
from sklearn.cluster import KMeans

# %%
X = image.reshape(-1,3)
kmeans = KMeans(n_clusters=8).fit(X)
segment_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segment_img.reshape(image.shape)

# %%
## Using Clustering for Preprocessing(응용)

# %%
from sklearn.datasets import load_digits
x_digits, y_digits = load_digits(return_X_y=True)
# Now, split it into a training set and a test set:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train)
#Next, fit a Logisitic Regression model:
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

#Let's evaluate its accuracy on the test set:
log_reg.score(X_test, y_test)

#50개로 군집화시킨다음에 그다음에 로지스틱 회귀를 쓰면 어떤 일이 일어날까 ?


#
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ("kmeans",KMeans(n_clusters=50)),
    ("log_reg", LogisticRegression()),
])
pipeline.fit(X_train, y_train)

#Now let's evaluate this classification pipeline:
pipeline.score(X_test,y_test)

#군집 후 로지스틱 회귀를 돌리면 스코어가 더 향상된다 !
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-446160b4086e> in <module>
#       3 # Now, split it into a training set and a test set:
#       4 from sklearn.model_selection import train_test_split
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X_train, y_train)
#       6 #Next, fit a Logisitic Regression model:
#       7 from sklearn.linear_model import LogisticRegression
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import GridSearchCV

param_grid = dict(kmeans_nclusters=range(2,100))
grid_clf = GridSearchCV(pipeline, param_grid, cv=3, verbose=2)
grid_clf.fit(X_train, y_train)

#Let's look at the best value for k and the performance of the resulting pipeline:

grid_clf.best_params_

grid_clf.score(X_test, y_test)

# %%
#준지도학습

y_representative_digits = np.array([1,23,412,612,2,15])

log_reg = LogiststicRegression()
log_reg.fit(X_representative_digits, y_representative_digits)
log_reg.score(X_test,y_test)

# %%
#레이블전파
# what if we propagated the labels to all the other instances in the same cluster?
